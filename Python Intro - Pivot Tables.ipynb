# %% [markdown]
# # Objective
#
# #### To provide a basic overview of creating pivot tables in Python

# %%
# Load packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os as os

# %%
# Get current working directory

os.getcwd()
# Out:
# '/Users/Patrick/Desktop'

# %%
# Change the working directory

os.chdir('/Users/Patrick/Desktop')

# %%
# Load the 2014 - 2018 NHL Scores data

nhl = pd.read_csv('2014-2018 NHL Scores.csv')

# %%
# Look at the first few rows

nhl.head()
# Out:
#       Season     Date              Visitor  G                 Home  G.1  \
# 0  2014-2015  10/8/14  Philadelphia Flyers  1        Boston Bruins    2
# 1  2014-2015  10/8/14    Vancouver Canucks  4       Calgary Flames    2
# 2  2014-2015  10/8/14      San Jose Sharks  4    Los Angeles Kings    0
# 3  2014-2015  10/8/14   Montreal Canadiens  4  Toronto Maple Leafs    3
# 4  2014-2015  10/9/14        Winnipeg Jets  6      Arizona Coyotes    2
#
#   Unnamed: 6   Att.  LOG  Notes
# 0        NaN  17565  NaN    NaN
# 1        NaN  19289  NaN    NaN
# 2        NaN  18514  NaN    NaN
# 3        NaN  19745  NaN    NaN
# 4        NaN  17125  NaN    NaN

# %% [markdown]
# > The "G" column is repeated so the second time it gets the name "G.1". Let's change those two column names to reflect the vistor goals and the home goals, respectively.

# %%
nhl = nhl.rename(columns = {'G': 'Visitor_G', 'G.1': 'Home_G'})

# %% [markdown]
# ### Create a point differential column

# %%
nhl['Point_Diff'] = nhl['Home_G'] - nhl['Visitor_G']

# %%
nhl.head()
# Out:
#       Season     Date              Visitor  Visitor_G                 Home  \
# 0  2014-2015  10/8/14  Philadelphia Flyers          1        Boston Bruins
# 1  2014-2015  10/8/14    Vancouver Canucks          4       Calgary Flames
# 2  2014-2015  10/8/14      San Jose Sharks          4    Los Angeles Kings
# 3  2014-2015  10/8/14   Montreal Canadiens          4  Toronto Maple Leafs
# 4  2014-2015  10/9/14        Winnipeg Jets          6      Arizona Coyotes
#
#    Home_G Unnamed: 6   Att.  LOG  Notes  Point_Diff
# 0       2        NaN  17565  NaN    NaN           1
# 1       2        NaN  19289  NaN    NaN          -2
# 2       0        NaN  18514  NaN    NaN          -4
# 3       3        NaN  19745  NaN    NaN          -1
# 4       2        NaN  17125  NaN    NaN          -4

# %% [markdown]
# ### Create a column identifying whether the home or visitor team won

# %%
conditions = [
    (nhl['Home_G'] > nhl['Visitor_G']),
    (nhl['Home_G'] < nhl['Visitor_G']),
    (nhl['Home_G'] == nhl['Visitor_G'])]

choices = ['home', 'visitor', 'tie']

# %%
nhl['winner'] = np.select(conditions, choices, default = 'null')

# %%
nhl.head()
# Out:
#       Season     Date              Visitor  Visitor_G                 Home  \
# 0  2014-2015  10/8/14  Philadelphia Flyers          1        Boston Bruins
# 1  2014-2015  10/8/14    Vancouver Canucks          4       Calgary Flames
# 2  2014-2015  10/8/14      San Jose Sharks          4    Los Angeles Kings
# 3  2014-2015  10/8/14   Montreal Canadiens          4  Toronto Maple Leafs
# 4  2014-2015  10/9/14        Winnipeg Jets          6      Arizona Coyotes
#
#    Home_G Unnamed: 6   Att.  LOG  Notes  Point_Diff   winner
# 0       2        NaN  17565  NaN    NaN           1     home
# 1       2        NaN  19289  NaN    NaN          -2  visitor
# 2       0        NaN  18514  NaN    NaN          -4  visitor
# 3       3        NaN  19745  NaN    NaN          -1  visitor
# 4       2        NaN  17125  NaN    NaN          -4  visitor

# %% [markdown]
# ### Create a column listing the winning and losing teams

# %%
cond_for_winner = [
    (nhl['winner'] == 'home'),
    (nhl['winner'] == 'visitor'),
    (nhl['winner'] == 'tie')]

choices_for_winner = [nhl['Home'], nhl['Visitor'], 'tie']
choices_for_loser = [nhl['Visitor'], nhl['Home'], 'tie']

# %%
nhl['winning_team'] = np.select(cond_for_winner, choices_for_winner, default = 'null')
nhl['losing_team'] = np.select(cond_for_winner, choices_for_loser, default = 'null')

# %%
nhl.head()
# Out:
#       Season     Date              Visitor  Visitor_G                 Home  \
# 0  2014-2015  10/8/14  Philadelphia Flyers          1        Boston Bruins
# 1  2014-2015  10/8/14    Vancouver Canucks          4       Calgary Flames
# 2  2014-2015  10/8/14      San Jose Sharks          4    Los Angeles Kings
# 3  2014-2015  10/8/14   Montreal Canadiens          4  Toronto Maple Leafs
# 4  2014-2015  10/9/14        Winnipeg Jets          6      Arizona Coyotes
#
#    Home_G Unnamed: 6   Att.  LOG  Notes  Point_Diff   winner  \
# 0       2        NaN  17565  NaN    NaN           1     home
# 1       2        NaN  19289  NaN    NaN          -2  visitor
# 2       0        NaN  18514  NaN    NaN          -4  visitor
# 3       3        NaN  19745  NaN    NaN          -1  visitor
# 4       2        NaN  17125  NaN    NaN          -4  visitor
#
#          winning_team          losing_team
# 0       Boston Bruins  Philadelphia Flyers
# 1   Vancouver Canucks       Calgary Flames
# 2     San Jose Sharks    Los Angeles Kings
# 3  Montreal Canadiens  Toronto Maple Leafs
# 4       Winnipeg Jets      Arizona Coyotes

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### Get the average point differential by season

# %%
nhl.groupby('Season').mean()['Point_Diff']
# Out:
# Season
# 2014-2015    0.244715
# 2015-2016    0.206504
# 2016-2017    0.316260
# 2017-2018    0.313139
# 2018-2019    0.305271
# Name: Point_Diff, dtype: float64

# %% [markdown]
# ##### That doesn't look as nice. Let's make it into a pivot table

# %%
nhl.pivot_table(values = 'Point_Diff', index = 'Season', aggfunc = np.mean)
# Out:
#            Point_Diff
# Season
# 2014-2015    0.244715
# 2015-2016    0.206504
# 2016-2017    0.316260
# 2017-2018    0.313139
# 2018-2019    0.305271

# %% [markdown]
# #### How many times did the home team win versus the away team?

# %%
nhl.groupby(['winner']).size()
# Out:
# winner
# home       3403
# visitor    2829
# dtype: int64

# %% [markdown]
# #### Now make it a probability by dividing the results by the number of rows in the data

# %%
nhl.groupby(['winner']).size() / len(nhl.index)
# Out:
# winner
# home       0.546053
# visitor    0.453947
# dtype: float64

# %% [markdown]
# #### What is the percent of home team's winning in each season?

# %%
season_totals = nhl.groupby(['Season', 'winner']).size().unstack()
season_totals['Home_Win_Pct'] = season_totals['home'] / (season_totals['home'] + season_totals['visitor'])
season_totals['Visitor_Win_Pct'] = season_totals['visitor'] / (season_totals['home'] + season_totals['visitor'])
season_totals
# Out:
# winner     home  visitor  Home_Win_Pct  Visitor_Win_Pct
# Season
# 2014-2015   666      564      0.541463         0.458537
# 2015-2016   651      579      0.529268         0.470732
# 2016-2017   688      542      0.559350         0.440650
# 2017-2018   716      555      0.563336         0.436664
# 2018-2019   682      589      0.536585         0.463415

# %% [markdown]
# ## What is each team's win percentage over the seasons in the data?

# %%
team_win_totals = nhl.groupby(['winning_team']).size()
team_loss_totals = nhl.groupby(['losing_team']).size()

team_win_totals = pd.DataFrame(team_win_totals, columns = ['wins'])
team_loss_totals = pd.DataFrame(team_loss_totals, columns = ['losses'])
team_perf = team_win_totals.join(team_loss_totals)

team_perf['Win_Pct'] = team_perf['wins'] / (team_perf['wins'] + team_perf['losses'])
team_perf.sort_values(by = ['Win_Pct'], ascending = False)
# Out:
#                        wins  losses   Win_Pct
# winning_team
# Tampa Bay Lightning     254     156  0.619512
# Washington Capitals     253     157  0.617073
# Vegas Golden Knights     94      70  0.573171
# St. Louis Blues         235     175  0.573171
# Pittsburgh Penguins     232     178  0.565854
# Nashville Predators     229     181  0.558537
# Boston Bruins           226     184  0.551220
# San Jose Sharks         223     187  0.543902
# Anaheim Ducks           222     188  0.541463
# Columbus Blue Jackets   218     192  0.531707
# Winnipeg Jets           217     193  0.529268
# New York Islanders      216     194  0.526829
# Minnesota Wild          215     195  0.524390
# Chicago Blackhawks      214     196  0.521951
# New York Rangers        213     197  0.519512
# Calgary Flames          212     198  0.517073
# Dallas Stars            210     200  0.512195
# Montreal Canadiens      208     202  0.507317
# Los Angeles Kings       203     207  0.495122
# Florida Panthers        200     210  0.487805
# Toronto Maple Leafs     194     216  0.473171
# Philadelphia Flyers     192     218  0.468293
# Carolina Hurricanes     183     227  0.446341
# Ottawa Senators         182     228  0.443902
# Colorado Avalanche      181     229  0.441463
# Detroit Red Wings       179     231  0.436585
# Vancouver Canucks       175     235  0.426829
# New Jersey Devils       173     237  0.421951
# Edmonton Oilers         173     237  0.421951
# Arizona Coyotes         157     253  0.382927
# Buffalo Sabres          149     261  0.363415
